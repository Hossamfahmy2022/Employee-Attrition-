# %%
import pandas as pd
import numpy as np
import plotly.express as px
import missingno as msg

# %%
df = pd.read_csv("Data.csv")

# %% [markdown]
# ### Big Picture On Data

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
msg.matrix(df)
# Out:
# <Axes: >

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.describe(include='object')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
# drop Over18 because it has only one value
df.drop(columns=['Over18'], inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Uni Varinte

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
px.histogram(df, x='Age')

# %%
df["Age"].describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
df[df["Age"]==60]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 411                  7          3  Life Sciences              1
# 427                 28          3      Marketing              1
# 536                 16          4      Marketing              1
# 879                  7          4      Marketing              1
# 1209                 1          4        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df["Attrition"].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
px.histogram(df, x='Attrition')

# %%
df["BusinessTravel"].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df["DailyRate"].describe()
# Out:
# count    1470.000000
# mean      802.485714
# std       403.509100
# min       102.000000
# 25%       465.000000
# 50%       802.000000
# 75%      1157.000000
# max      1499.000000
# Name: DailyRate, dtype: float64

# %%
df[df["DailyRate"]==df["DailyRate"].min()] # not logical until now
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 649   53        No  Travel_Rarely        102  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 649                23          4  Life Sciences              1
#
#      EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 649             901  ...                         3            80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 649                 0                 33                      0
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 649               3              12                  9
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 649                        3                     8
#
# [1 rows x 34 columns]

# %%
df[df["DailyRate"]==df["DailyRate"].max()]
# Out:
#      Age Attrition     BusinessTravel  DailyRate Department  DistanceFromHome  \
# 427   60        No  Travel_Frequently       1499      Sales                28
#
#      Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 427          3      Marketing              1             573  ...
#
#      RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 427                         4            80                 0
#
#      TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 427                 22                      5               4              18
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 427                 13                       13                    11
#
# [1 rows x 34 columns]

# %%
px.histogram(df, x='DailyRate')

# %%
df["Department"].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df["Department"].value_counts(normalize=True)
# Out:
# Department
# Research & Development    0.653741
# Sales                     0.303401
# Human Resources           0.042857
# Name: proportion, dtype: float64

# %%
#make it sorted with highest percentage
px.histogram(df, x='Department', category_orders={"Department":df["Department"].value_counts().index})

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df["DistanceFromHome"].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
df[df["DistanceFromHome"]==df["DistanceFromHome"].max()].shape[0]
# Out:
# 27

# %%
df[df["DistanceFromHome"]==df["DistanceFromHome"].min()].shape[0]
# Out:
# 208

# %%
px.histogram(df, x='DistanceFromHome')

# %%
df["Education"].value_counts()
# Out:
# Education
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: count, dtype: int64

# %% [markdown]
# .The data represents the distribution of employees across different education levels, with each level being coded numerically (1 to 5). Here is a breakdown:
#
# 1 (Below College): 170 employees.
# 2 (College): 282 employees.
# 3 (Bachelor): 572 employees. This is the largest group, indicating most employees have a bachelor's degree.
# 4 (Master): 398 employees.
# 5 (Doctorate): 48 employees. This is the smallest group, representing employees with the highest level of education.

# %%
education_mapping = {
    1: "Below College",
    2: "College",
    3: "Bachelor",
    4: "Master",
    5: "Doctorate"
}
df["EducationCatergory"] = df["Education"].map(education_mapping)

# %%
df["EducationCatergory"].value_counts()
# Out:
# EducationCatergory
# Bachelor         572
# Master           398
# College          282
# Below College    170
# Doctorate         48
# Name: count, dtype: int64

# %%
df["EducationCatergory"].value_counts(normalize=True)
# Out:
# EducationCatergory
# Bachelor         0.389116
# Master           0.270748
# College          0.191837
# Below College    0.115646
# Doctorate        0.032653
# Name: proportion, dtype: float64

# %%
px.histogram(df, x='EducationCatergory', category_orders={"EducationCatergory":df["EducationCatergory"].value_counts().index})

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'EducationCatergory'],
#       dtype='object')

# %%
df["EducationField"].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df["EducationField"].value_counts(normalize=True)
# Out:
# EducationField
# Life Sciences       0.412245
# Medical             0.315646
# Marketing           0.108163
# Technical Degree    0.089796
# Other               0.055782
# Human Resources     0.018367
# Name: proportion, dtype: float64

# %%
px.histogram(df, x='EducationField', category_orders={"EducationField":df["EducationField"].value_counts().index})

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'EducationCatergory'],
#       dtype='object')

# %%
df["EmployeeCount"].value_counts()
# Out:
# EmployeeCount
# 1    1470
# Name: count, dtype: int64

# %%
df.drop(columns=["EmployeeCount"], inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["EmployeeNumber"].nunique()
# Out:
# 1470

# %%
df.drop(columns=["EmployeeNumber"], inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#JobSatisfaction: A rating of the employee's satisfaction with their job (1 = Low, 4 = Very High).
df["EnvironmentSatisfaction"].value_counts()
# Out:
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: count, dtype: int64

# %%
env_satisfaction_mapping = {
    1: "Low",
    2: "Medium",
    3: "High",
    4: "Very High"
}
df["EnvironmentSatisfaction_Catergories"] = df["EnvironmentSatisfaction"].map(env_satisfaction_mapping)

# %%
df["EnvironmentSatisfaction_Catergories"].value_counts()
# Out:
# EnvironmentSatisfaction_Catergories
# High         453
# Very High    446
# Medium       287
# Low          284
# Name: count, dtype: int64

# %%
df["EnvironmentSatisfaction_Catergories"].value_counts(normalize=True)
# Out:
# EnvironmentSatisfaction_Catergories
# High         0.308163
# Very High    0.303401
# Medium       0.195238
# Low          0.193197
# Name: proportion, dtype: float64

# %%
px.histogram(df, x='EnvironmentSatisfaction_Catergories', category_orders={"EnvironmentSatisfaction_Catergories":df["EnvironmentSatisfaction_Catergories"].value_counts().index})

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
df["Gender"].value_counts(normalize=True)
# Out:
# Gender
# Male      0.6
# Female    0.4
# Name: proportion, dtype: float64

# %%
px.histogram(data_frame=df,x="Gender",category_orders={"Gender":df["Gender"].value_counts().index})

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EducationCatergory', 'EnvironmentSatisfaction_Catergories'],
#       dtype='object')

# %%
df["HourlyRate"].describe()
# Out:
# count    1470.000000
# mean       65.891156
# std        20.329428
# min        30.000000
# 25%        48.000000
# 50%        66.000000
# 75%        83.750000
# max       100.000000
# Name: HourlyRate, dtype: float64

# %%
px.histogram(df, x='HourlyRate')

# %%
# JobInvolvement: A rating of the employee's job involvement (1 = Low, 4 = Very High).
df["JobInvolvement"].value_counts()
# Out:
# JobInvolvement
# 3    868
# 2    375
# 4    144
# 1     83
# Name: count, dtype: int64

# %%
# map the values to catergories
job_involvement_mapping = {
    1: "Low",
    2: "Medium",
    3: "High",
    4: "Very High"
}
df["JobInvolvement_Catergories"] = df["JobInvolvement"].map(job_involvement_mapping)

# %%
px.histogram(df, x='JobInvolvement_Catergories', category_orders={"JobInvolvement_Catergories":df["JobInvolvement_Catergories"].value_counts().index})

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EducationCatergory', 'EnvironmentSatisfaction_Catergories',
#        'JobInvolvement_Catergories'],
#       dtype='object')

# %%
#JobLevel: The employee's job level or hierarchy within the organization.
df["JobLevel"].value_counts()
# Out:
# JobLevel
# 1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: count, dtype: int64

# %%
# map the values to catergories
job_level_mapping = {
    1: "Entry Level",
    2: "Mid Level",
    3: "Senior Level",
    4: "Executive Level",
    5: "Top Level"
}
df["JobLevel_Catergories"] = df["JobLevel"].map(job_level_mapping)

# %%
px.histogram(df, x='JobLevel_Catergories', category_orders={"JobLevel_Catergories":df["JobLevel_Catergories"].value_counts().index})

# %%
df["JobRole"].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
px.histogram(df, x='JobRole', category_orders={"JobRole":df["JobRole"].value_counts().index})

# %%
#JobSatisfaction: A rating of the employee's satisfaction with their job (1 = Low, 4 = Very High).
df["JobSatisfaction"].value_counts()
# Out:
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: count, dtype: int64

# %%
# map the values to catergories
job_satisfaction_mapping = {
    1: "Low",
    2: "Medium",
    3: "High",
    4: "Very High"
}
df["JobSatisfaction_Catergories"] = df["JobSatisfaction"].map(job_satisfaction_mapping)

# %%
px.histogram(df, x='JobSatisfaction_Catergories', category_orders={"JobSatisfaction_Catergories":df["JobSatisfaction_Catergories"].value_counts().index})

# %%
df["MonthlyIncome"].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
px.histogram(df, x='MonthlyIncome')

# %%
px.box(df, x='MonthlyIncome')

# %%
df["MonthlyRate"].describe()
# Out:
# count     1470.000000
# mean     14313.103401
# std       7117.786044
# min       2094.000000
# 25%       8047.000000
# 50%      14235.500000
# 75%      20461.500000
# max      26999.000000
# Name: MonthlyRate, dtype: float64

# %%
px.histogram(df, x='MonthlyRate')

# %%
px.box(df, x='MonthlyRate')

# %%
df[['MonthlyIncome', 'MonthlyRate']]
# Out:
#       MonthlyIncome  MonthlyRate
# 0              5993        19479
# 1              5130        24907
# 2              2090         2396
# 3              2909        23159
# 4              3468        16632
# ...             ...          ...
# 1465           2571        12290
# 1466           9991        21457
# 1467           6142         5174
# 1468           5390        13243
# 1469           4404        10228
#
# [1470 rows x 2 columns]

# %%
df[df['MonthlyIncome']> df['MonthlyRate']].shape[0]
# Out:
# 258

# %%
df[df['MonthlyIncome']> df['MonthlyRate']].head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 8    38        No  Travel_Frequently        216  Research & Development
# 25   53        No      Travel_Rarely       1282  Research & Development
# 28   44        No      Travel_Rarely        477  Research & Development
# 39   33        No  Travel_Frequently       1141                   Sales
# 43   27        No  Travel_Frequently        994                   Sales
#
#     DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 8                 23          3  Life Sciences                        4
# 25                 5          3          Other                        3
# 28                 7          4        Medical                        1
# 39                 1          3  Life Sciences                        3
# 43                 8          3  Life Sciences                        4
#
#     Gender  ...  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# ...

# %%
abs(df['MonthlyIncome']- df['MonthlyRate']).mean()
# Out:
# 9425.921768707483

# %%
df["NumCompaniesWorked"].value_counts()
# Out:
# NumCompaniesWorked
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: count, dtype: int64

# %%
px.histogram(df, x='NumCompaniesWorked')

# %%
df["OverTime"].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
px.histogram(df, x='OverTime')

# %%
df["PercentSalaryHike"].describe() # The percentage increase in the employee's salary.
# Out:
# count    1470.000000
# mean       15.209524
# std         3.659938
# min        11.000000
# 25%        12.000000
# 50%        14.000000
# 75%        18.000000
# max        25.000000
# Name: PercentSalaryHike, dtype: float64

# %%
#PerformanceRating: A performance rating for the employee (e.g., 1 = Low, 4 = Outstanding).
df["PerformanceRating"].value_counts()
# Out:
# PerformanceRating
# 3    1244
# 4     226
# Name: count, dtype: int64

# %%
# RelationshipSatisfaction: A rating of satisfaction with workplace relationships (1 = Low, 4 = Very High).
df["RelationshipSatisfaction"].value_counts()
# Out:
# RelationshipSatisfaction
# 3    459
# 4    432
# 2    303
# 1    276
# Name: count, dtype: int64

# %%
relationship_satisfaction_mapping = {
    1: "Low",
    2: "Medium",
    3: "High",
    4: "Very High"
}
# Map numeric values to descriptive labels
df["RelationshipSatisfaction_Desc"] = df["RelationshipSatisfaction"].map(relationship_satisfaction_mapping)

# %%
df["RelationshipSatisfaction_Desc"].value_counts()
# Out:
# RelationshipSatisfaction_Desc
# High         459
# Very High    432
# Medium       303
# Low          276
# Name: count, dtype: int64

# %%
# StandardHours: Likely the standard number of hours in a work week. This may be a constant value (e.g., 80).
df["StandardHours"].value_counts()
# Out:
# StandardHours
# 80    1470
# Name: count, dtype: int64

# %%
df.drop(columns=["StandardHours"], inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#StockOptionLevel: The level of stock options granted to the employee.
df["StockOptionLevel"].value_counts()
# Out:
# StockOptionLevel
# 0    631
# 1    596
# 2    158
# 3     85
# Name: count, dtype: int64

# %%
#TotalWorkingYears: The total number of years the employee has worked so far.
df["TotalWorkingYears"].describe()
# Out:
# count    1470.000000
# mean       11.279592
# std         7.780782
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        40.000000
# Name: TotalWorkingYears, dtype: float64

# %%
df[df["TotalWorkingYears"]==0].shape[0]
# Out:
# 11

# %%
#TrainingTimesLastYear: The number of training sessions attended by the employee in the last year.
df["TrainingTimesLastYear"].value_counts()
# Out:
# TrainingTimesLastYear
# 2    547
# 3    491
# 4    123
# 5    119
# 1     71
# 6     65
# 0     54
# Name: count, dtype: int64

# %%
px.histogram(df, x='TrainingTimesLastYear', category_orders={"TrainingTimesLastYear":df["TrainingTimesLastYear"].value_counts().index})

# %%
#WorkLifeBalance: A rating of the employee's work-life balance (1 = Bad, 4 = Excellent).
df["WorkLifeBalance"].value_counts()
# Out:
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: count, dtype: int64

# %%
work_life_balance_mapping = {
    1: "Bad",
    2: "Good",
    3: "Better",
    4: "Excellent"
}
df["WorkLifeBalance_Desc"] = df["WorkLifeBalance"].map(work_life_balance_mapping)

# %%
df["WorkLifeBalance_Desc"].value_counts()
# Out:
# WorkLifeBalance_Desc
# Better       893
# Good         344
# Excellent    153
# Bad           80
# Name: count, dtype: int64

# %%
px.histogram(df, x='WorkLifeBalance_Desc', category_orders={"WorkLifeBalance_Desc":df["WorkLifeBalance_Desc"].value_counts().index})

# %%
#YearsAtCompany: The number of years the employee has worked at the company.
df["YearsAtCompany"].describe()
# Out:
# count    1470.000000
# mean        7.008163
# std         6.126525
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %%
px.histogram(df, x='YearsAtCompany')

# %%
df["YearsInCurrentRole"].describe()
# Out:
# count    1470.000000
# mean        4.229252
# std         3.623137
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        18.000000
# Name: YearsInCurrentRole, dtype: float64

# %%
px.histogram(df, x='YearsInCurrentRole')

# %%
# YearsSinceLastPromotion: The number of years since the employee's last promotion.
df["YearsSinceLastPromotion"].describe()
# Out:
# count    1470.000000
# mean        2.187755
# std         3.222430
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        15.000000
# Name: YearsSinceLastPromotion, dtype: float64

# %%
px.histogram(df, x='YearsSinceLastPromotion')

# %%
# YearsWithCurrManager: The number of years the employee has worked with their current manager.
df["YearsWithCurrManager"].describe()
# Out:
# count    1470.000000
# mean        4.123129
# std         3.568136
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        17.000000
# Name: YearsWithCurrManager, dtype: float64

# %%
px.histogram(df, x='YearsWithCurrManager')

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'EducationCatergory',
#        'EnvironmentSatisfaction_Catergories', 'JobInvolvement_Catergories',
#        'JobLevel_Catergories', 'JobSatisfaction_Catergories',
#        'RelationshipSatisfaction_Desc', 'WorkLifeBalance_Desc'],
#       dtype='object')

# %%
# i need to map age to catergories 
def categorize_age(age):
    if 18 <= age <= 25:
        return "Young Adult"
    elif 26 <= age <= 35:
        return "Early Career"
    elif 36 <= age <= 50:
        return "Mid Career"
    elif age >= 51:
        return "Late Career"
    else:
        return "Unknown"

# Apply the function to create a new column
df['AgeCategory'] = df['Age'].apply(categorize_age)

# %%
px.histogram(df, x='AgeCategory', category_orders={"AgeCategory":df["AgeCategory"].value_counts().index})

# %% [markdown]
# ### BI VARINATE

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'EducationCatergory',
#        'EnvironmentSatisfaction_Catergories', 'JobInvolvement_Catergories',
#        'JobLevel_Catergories', 'JobSatisfaction_Catergories',
#        'RelationshipSatisfaction_Desc', 'WorkLifeBalance_Desc', 'AgeCategory'],
#       dtype='object')

# %%
cat_columns=df.select_dtypes(include='object').columns.to_list()
num_columns=df.select_dtypes(include='number').columns.to_list()

# %%
cat_columns
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime',
#  'EducationCatergory',
#  'EnvironmentSatisfaction_Catergories',
#  'JobInvolvement_Catergories',
#  'JobLevel_Catergories',
#  'JobSatisfaction_Catergories',
#  'RelationshipSatisfaction_Desc',
#  'WorkLifeBalance_Desc',
#  'AgeCategory']

# %%
num_columns
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
# i need to get relation between all numerical column and attrition
df.groupby("Attrition")["Age"].mean()
# Out:
# Attrition
# No     37.561233
# Yes    33.607595
# Name: Age, dtype: float64

# %%
px.box(df, x='Attrition', y='Age')

# %%
cat_columns
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime',
#  'EducationCatergory',
#  'EnvironmentSatisfaction_Catergories',
#  'JobInvolvement_Catergories',
#  'JobLevel_Catergories',
#  'JobSatisfaction_Catergories',
#  'RelationshipSatisfaction_Desc',
#  'WorkLifeBalance_Desc',
#  'AgeCategory']

# %%
df.groupby("BusinessTravel")["Attrition"].value_counts().to_frame()
# Out:
#                              count
# BusinessTravel    Attrition
# Non-Travel        No           138
#                   Yes           12
# Travel_Frequently No           208
#                   Yes           69
# Travel_Rarely     No           887
#                   Yes          156

# %%
df.groupby("BusinessTravel")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                              proportion
# BusinessTravel    Attrition
# Non-Travel        No           0.920000
#                   Yes          0.080000
# Travel_Frequently No           0.750903
#                   Yes          0.249097
# Travel_Rarely     No           0.850431
#                   Yes          0.149569

# %%
px.histogram(df, x='BusinessTravel', color='Attrition')

# %%
# Department vs Attrition
df.groupby("Department")["Attrition"].value_counts().to_frame()
# Out:
#                                   count
# Department             Attrition
# Human Resources        No            51
#                        Yes           12
# Research & Development No           828
#                        Yes          133
# Sales                  No           354
#                        Yes           92

# %%
px.histogram(df, x='Department', color='Attrition',)

# %%
# EducationField vs Attrition
df.groupby("EducationField")["Attrition"].value_counts().to_frame()
# Out:
#                             count
# EducationField   Attrition
# Human Resources  No            20
#                  Yes            7
# Life Sciences    No           517
#                  Yes           89
# Marketing        No           124
#                  Yes           35
# Medical          No           401
#                  Yes           63
# Other            No            71
#                  Yes           11
# Technical Degree No           100
#                  Yes           32

# %%
px.histogram(df, x='EducationField', color='Attrition')

# %%
cat_columns
# Out:
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime',
#  'EducationCatergory',
#  'EnvironmentSatisfaction_Catergories',
#  'JobInvolvement_Catergories',
#  'JobLevel_Catergories',
#  'JobSatisfaction_Catergories',
#  'RelationshipSatisfaction_Desc',
#  'WorkLifeBalance_Desc',
#  'AgeCategory']

# %%
# Gender vs Attrition
df.groupby("Attrition")["Gender"].value_counts().to_frame()
# Out:
#                   count
# Attrition Gender
# No        Male      732
#           Female    501
# Yes       Male      150
#           Female     87

# %%
px.histogram(df, x='Gender', color='Attrition')

# %%
## Correlation from seaborn
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 20))
sns.heatmap(df[num_columns].corr(), annot=True, cmap='coolwarm', center=0)
# Out:
# <Axes: >

# %% [markdown]
# ### QA

# %%
## 1. What is the average monthly income by job role?
df.groupby("JobRole")["MonthlyIncome"].mean().sort_values(ascending=False).to_frame()
# Out:
#                            MonthlyIncome
# JobRole
# Manager                     17181.676471
# Research Director           16033.550000
# Healthcare Representative    7528.763359
# Manufacturing Director       7295.137931
# Sales Executive              6924.279141
# Human Resources              4235.750000
# Research Scientist           3239.972603
# Laboratory Technician        3237.169884
# Sales Representative         2626.000000

# %%
## 2. How does attrition vary by work-life balance?
df.groupby("WorkLifeBalance_Desc")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                                 proportion
# WorkLifeBalance_Desc Attrition
# Bad                  No           0.687500
#                      Yes          0.312500
# Better               No           0.857783
#                      Yes          0.142217
# Excellent            No           0.823529
#                      Yes          0.176471
# Good                 No           0.831395
#                      Yes          0.168605

# %%
px.histogram(df, x='WorkLifeBalance_Desc', color='Attrition')

# %%
## 3. What is the relationship between years at the company and performance ratings?
df.groupby("PerformanceRating")["YearsAtCompany"].mean().to_frame()
# Out:
#                    YearsAtCompany
# PerformanceRating
# 3                        6.999196
# 4                        7.057522

# %%
px.box(df, x='PerformanceRating', y='YearsAtCompany')

# %%
## 4. Which department has the highest job satisfaction on average?
df.groupby("Department")["JobSatisfaction"].mean().sort_values(ascending=False).to_frame()
# Out:
#                         JobSatisfaction
# Department
# Sales                          2.751121
# Research & Development         2.726327
# Human Resources                2.603175

# %%
px.bar(df, x='Department', y='JobSatisfaction', color='Department',)

# %%
## 5. How does distance from home affect monthly income?
df.groupby("DistanceFromHome")["MonthlyIncome"].mean().to_frame()
# Out:
#                   MonthlyIncome
# DistanceFromHome
# 1                   6513.240385
# 2                   6964.004739
# 3                   6589.226190
# 4                   7060.890625
# 5                   6442.415385
# 6                   6231.440678
# 7                   6839.035714
# 8                   6271.987500
# 9                   5521.376471
# 10                  6503.081395
# 11                  6857.931034
# 12                  6493.550000
# 13                  5710.368421
# 14                  6481.809524
# 15                  7631.076923
# 16                  5253.625000
# 17                  6103.050000
# 18                  6481.923077
# 19                  4675.954545
# 20                  5948.280000
# 21                  5094.555556
# 22                  7687.894737
# 23                  5780.777778
# 24                  5322.285714
# 25                  6671.960000
# 26                  8951.960000
# 27                  5587.583333
# ...

# %%
px.scatter(df, x='DistanceFromHome', y='MonthlyIncome')

# %%
## 6. Does work-life balance affect attrition?
df.groupby("WorkLifeBalance_Desc")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                                 proportion
# WorkLifeBalance_Desc Attrition
# Bad                  No           0.687500
#                      Yes          0.312500
# Better               No           0.857783
#                      Yes          0.142217
# Excellent            No           0.823529
#                      Yes          0.176471
# Good                 No           0.831395
#                      Yes          0.168605

# %%
px.histogram(df, x='WorkLifeBalance_Desc', color='Attrition')

# %%
## 2. Does job satisfaction correlate with attrition?
df.groupby("JobSatisfaction")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                            proportion
# JobSatisfaction Attrition
# 1               No           0.771626
#                 Yes          0.228374
# 2               No           0.835714
#                 Yes          0.164286
# 3               No           0.834842
#                 Yes          0.165158
# 4               No           0.886710
#                 Yes          0.113290

# %%
px.histogram(df, x='JobSatisfaction', color='Attrition')

# %%
# 3. Does distance from home influence attrition?
df.groupby("DistanceFromHome")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                             proportion
# DistanceFromHome Attrition
# 1                No           0.875000
#                  Yes          0.125000
# 2                No           0.867299
#                  Yes          0.132701
# 3                No           0.833333
#                  Yes          0.166667
# 4                No           0.859375
#                  Yes          0.140625
# 5                No           0.846154
#                  Yes          0.153846
# 6                No           0.881356
#                  Yes          0.118644
# 7                No           0.869048
#                  Yes          0.130952
# 8                No           0.875000
#                  Yes          0.125000
# 9                No           0.788235
#                  Yes          0.211765
# 10               No           0.872093
#                  Yes          0.127907
# 11               No           0.862069
#                  Yes          0.137931
# ...

# %%
px.bar(df, x='DistanceFromHome', y='Attrition', color='Attrition')

# %%
# 4. Does overtime correlate with attrition?
df.groupby("OverTime")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                     proportion
# OverTime Attrition
# No       No           0.895636
#          Yes          0.104364
# Yes      No           0.694712
#          Yes          0.305288

# %%
px.histogram(df, x='OverTime', color='Attrition')

# %%
# 5. Does income level influence attrition?
df["IncomeLevel"] = pd.cut(df["MonthlyIncome"], bins=3, labels=["Low", "Medium", "High"])

# %%
# 5. Does job role correlate with attrition?
df.groupby("JobRole")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                                      proportion
# JobRole                   Attrition
# Healthcare Representative No           0.931298
#                           Yes          0.068702
# Human Resources           No           0.769231
#                           Yes          0.230769
# Laboratory Technician     No           0.760618
#                           Yes          0.239382
# Manager                   No           0.950980
#                           Yes          0.049020
# Manufacturing Director    No           0.931034
#                           Yes          0.068966
# Research Director         No           0.975000
#                           Yes          0.025000
# Research Scientist        No           0.839041
#                           Yes          0.160959
# Sales Executive           No           0.825153
#                           Yes          0.174847
# Sales Representative      No           0.602410
#                           Yes          0.397590

# %%
px.histogram(df, x='JobRole', color='Attrition')

# %%
# 6. Does tenure affect attrition?
df.groupby("YearsAtCompany")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                           proportion
# YearsAtCompany Attrition
# 0              No           0.636364
#                Yes          0.363636
# 1              No           0.654971
#                Yes          0.345029
# 2              No           0.787402
# ...                              ...
# 33             Yes          0.200000
# 34             No           1.000000
# 36             No           1.000000
# 37             No           1.000000
# 40             Yes          1.000000
#
# [64 rows x 1 columns]

# %%
px.bar(df, x='YearsAtCompany', y='Attrition', color='Attrition')

# %%
# 8. Do stock options impact attrition?
df.groupby("StockOptionLevel")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                             proportion
# StockOptionLevel Attrition
# 0                No           0.755943
#                  Yes          0.244057
# 1                No           0.906040
#                  Yes          0.093960
# 2                No           0.924051
#                  Yes          0.075949
# 3                No           0.823529
#                  Yes          0.176471

# %%
px.histogram(df, x='StockOptionLevel', color='Attrition')

# %%
# 9. Does relationship satisfaction impact attrition?
df.groupby("RelationshipSatisfaction_Desc")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                                          proportion
# RelationshipSatisfaction_Desc Attrition
# High                          No           0.845316
#                               Yes          0.154684
# Low                           No           0.793478
#                               Yes          0.206522
# Medium                        No           0.851485
#                               Yes          0.148515
# Very High                     No           0.851852
#                               Yes          0.148148

# %%
px.histogram(df, x='RelationshipSatisfaction_Desc', color='Attrition')

# %%
# 10. Does work-life balance impact attrition?
df.groupby("WorkLifeBalance_Desc")["Attrition"].value_counts(normalize=True).to_frame()
# Out:
#                                 proportion
# WorkLifeBalance_Desc Attrition
# Bad                  No           0.687500
#                      Yes          0.312500
# Better               No           0.857783
#                      Yes          0.142217
# Excellent            No           0.823529
#                      Yes          0.176471
# Good                 No           0.831395
#                      Yes          0.168605

# %%
px.histogram(df, x='WorkLifeBalance_Desc', color='Attrition')

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'EducationCatergory',
#        'EnvironmentSatisfaction_Catergories', 'JobInvolvement_Catergories',
#        'JobLevel_Catergories', 'JobSatisfaction_Catergories',
#        'RelationshipSatisfaction_Desc', 'WorkLifeBalance_Desc', 'AgeCategory'],
#       dtype='object')

# %%
df.drop(columns=[
    'EnvironmentSatisfaction_Catergories', 'JobInvolvement_Catergories',
       'JobLevel_Catergories', 'JobSatisfaction_Catergories',
       'RelationshipSatisfaction_Desc', 'WorkLifeBalance_Desc', 'AgeCategory'
    ],inplace=True,axis=1)

# %%
df.drop(columns=['EducationCatergory'],inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder , StandardScaler , LabelEncoder , RobustScaler
from sklearn.impute import SimpleImputer , KNNImputer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 
from sklearn.naive_bayes import MultinomialNB , GaussianNB
from sklearn.model_selection import train_test_split , cross_validate
from sklearn.metrics import accuracy_score , recall_score , precision_score , f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
x = df.drop("Attrition" , axis = 1 )
y = df["Attrition"]

# %%
y = LabelEncoder().fit_transform(y)
# Out:
# c:\Users\Hossam\anaconda3\envs\churn\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# c:\Users\Hossam\anaconda3\envs\churn\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.

# %%
Num_Columns = x.select_dtypes(include="number")
Cat_Columns = x.select_dtypes(include="object_")

# %%
Num_Steps = list()
Num_Steps.append(("Num_Imputer" , KNNImputer()))
Num_Steps.append(("Scaler" , StandardScaler()))
Num_Pipeline = Pipeline(steps=Num_Steps)

# %%
Cat_Steps = list()
Cat_Steps.append(("Cat_Imputer" , SimpleImputer(strategy='most_frequent')))
Cat_Steps.append(("Cat_Encoder" , OneHotEncoder(sparse_output=False , drop='first')))
Cat_Pipeline = Pipeline(steps= Cat_Steps)

# %%
Transformer = ColumnTransformer(transformers=[('Num' , Num_Pipeline , Num_Columns.columns) , 
                                              ('Cat' , Cat_Pipeline , Cat_Columns.columns) ] , remainder='passthrough')

# %%
steps = list()
steps.append(("Preprocessing" , Transformer))
steps.append(("Model" , LogisticRegression()))
pipeline = Pipeline(steps=steps)

# %%
results = cross_validate(pipeline , x , y , scoring="accuracy"  ,cv = 5 , return_train_score=True)

# %%
results["train_score"].mean()
# Out:
# 0.8952380952380953

# %%
results["test_score"].mean()
# Out:
# 0.8816326530612244

# %%
models = list()
models.append(("LR" , LogisticRegression()))
#models.append(("MNBA" , MultinomialNB()))
models.append(("GNB" , GaussianNB()))
models.append(("SVM" , SVC()))
models.append(("CART" , DecisionTreeClassifier()))
models.append(("RF" , RandomForestClassifier()))
models.append(("XG" , XGBClassifier()))
models.append(("KNN" , KNeighborsClassifier()))

# %%
for model in models:
    steps = list()
    steps.append(("Preprocessing" , Transformer))
    steps.append(model)
    pipeline = Pipeline(steps = steps)
    scores = cross_validate(pipeline , x , y , scoring="accuracy"  ,cv = 5 , return_train_score=True)
    print(model[0])
    print("Train_accuracy" , scores["train_score"].mean() )
    print("-" * 10)
    print("Test_accuracy" , scores["test_score"].mean())
    print("-" * 20)
    print("\n")
# Out:
# LR
# Train_accuracy 0.8952380952380953
# ----------
# Test_accuracy 0.8816326530612244
# --------------------
#
#
# GNB
# Train_accuracy 0.6656462585034013
# ----------
# Test_accuracy 0.6591836734693878
# --------------------
#
#
# SVM
# Train_accuracy 0.9105442176870747
# ----------
# Test_accuracy 0.8625850340136054
# --------------------
#
#
# CART
# Train_accuracy 1.0
# ----------
# Test_accuracy 0.7931972789115646
# --------------------
#
#
# RF
# Train_accuracy 1.0
# ----------
# Test_accuracy 0.8591836734693878
# --------------------
#
#
# XG
# Train_accuracy 1.0
# ----------
# Test_accuracy 0.8673469387755102
# --------------------
#
#
# KNN
# Train_accuracy 0.8734693877551021
# ----------
# Test_accuracy 0.84421768707483
# --------------------

# %%
steps = list()
steps.append(("Preprocessing" , Transformer))
steps.append(("SVM" , SVC()))
pipeline = Pipeline(steps = steps)
scores = cross_validate(pipeline , x , y , scoring="accuracy"  ,cv = 5 , return_train_score=True,return_estimator=True)
print("Train_accuracy" , scores["train_score"].mean() )
print("-" * 10)
print("Test_accuracy" , scores["test_score"].mean())
print("-" * 20)
print("\n")
# Out:
# Train_accuracy 0.9105442176870747
# ----------
# Test_accuracy 0.8625850340136054
# --------------------

# %%
pipeline["SVM"].get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
from sklearn.model_selection import GridSearchCV
params = [
        {'SVM__C':[0.5,1,2,3,5], 'SVM__kernel':['linear', 'sigmoid', 'poly']},
        {'SVM__C':[0.5,1,2,3,5], 'SVM__kernel':['rbf'], 'SVM__gamma':[0.5, 0.6, 0.7, 0.1, 0.01, 0.05,"scale"]},
        {'SVM__C':[0.5,1,2,3,5], 'SVM__kernel':['poly'] , "SVM__degree" :[2,3,4,5]},
         ]

# %%
steps = list()
steps.append(("Preprocessing" , Transformer))
steps.append(("SVM" , SVC()))
pipeline = Pipeline(steps = steps)

# %%
grid_search = GridSearchCV(estimator=pipeline,
                           param_grid=params,
                           scoring='accuracy',
                           cv=5, n_jobs=-1,return_train_score=True)
grid_search.fit(x, y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Preprocessing',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('Num',
#                                                                          Pipeline(steps=[('Num_Imputer',
#                                                                                           KNNImputer()),
#                                                                                          ('Scaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIn...
#        'MaritalStatus', 'OverTime'],
# ...

# %%
grid_search.cv_results_["mean_test_score"].mean()
# Out:
# 0.8540524781341108

# %%
grid_search.cv_results_["mean_train_score"].mean()
# Out:
# 0.9345578231292517

# %%
Final_pipeline=grid_search.best_estimator_

# %%
Final_pipeline.fit(x,y)
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Num',
#                                                   Pipeline(steps=[('Num_Imputer',
#                                                                    KNNImputer()),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumComp...
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')),
#                                                  ('Cat',
#                                                   Pipeline(steps=[('Cat_Imputer',
# ...

# %%
import joblib

# %%
joblib.dump(Final_pipeline , "Model.pkl")
joblib.dump(x.columns,"Inputs.pkl")
# Out:
# ['Inputs.pkl']

# %%
x.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
Model = joblib.load("Model.pkl")

# %%
Model.predict(df.drop("Attrition" , axis = 1 ).iloc[0:5])
# Out:
# array([1, 0, 1, 0, 0])

# %%
import streamlit as st
import numpy as np
import joblib
import pandas as pd
import numpy as np
import streamlit as st

Model = joblib.load("Model.pkl")
Inputs = joblib.load("inputs.pkl")



def prediction(Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, 
               EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, 
               JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, 
               OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StockOptionLevel, 
               TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, 
               YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager):
    
    # Define the list of input columns
    Inputs = ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 
              'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 
              'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 
              'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 
              'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 
              'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 
              'YearsWithCurrManager']
    
    # Create a DataFrame and fill in the provided values
    df = pd.DataFrame(columns=Inputs)
    df.at[0, "Age"] = Age
    df.at[0, "BusinessTravel"] = BusinessTravel
    df.at[0, "DailyRate"] = DailyRate
    df.at[0, "Department"] = Department
    df.at[0, "DistanceFromHome"] = DistanceFromHome
    df.at[0, "Education"] = Education
    df.at[0, "EducationField"] = EducationField
    df.at[0, "EnvironmentSatisfaction"] = EnvironmentSatisfaction
    df.at[0, "Gender"] = Gender
    df.at[0, "HourlyRate"] = HourlyRate
    df.at[0, "JobInvolvement"] = JobInvolvement
    df.at[0, "JobLevel"] = JobLevel
    df.at[0, "JobRole"] = JobRole
    df.at[0, "JobSatisfaction"] = JobSatisfaction
    df.at[0, "MaritalStatus"] = MaritalStatus
    df.at[0, "MonthlyIncome"] = MonthlyIncome
    df.at[0, "MonthlyRate"] = MonthlyRate
    df.at[0, "NumCompaniesWorked"] = NumCompaniesWorked
    df.at[0, "OverTime"] = OverTime
    df.at[0, "PercentSalaryHike"] = PercentSalaryHike
    df.at[0, "PerformanceRating"] = PerformanceRating
    df.at[0, "RelationshipSatisfaction"] = RelationshipSatisfaction
    df.at[0, "StockOptionLevel"] = StockOptionLevel
    df.at[0, "TotalWorkingYears"] = TotalWorkingYears
    df.at[0, "TrainingTimesLastYear"] = TrainingTimesLastYear
    df.at[0, "WorkLifeBalance"] = WorkLifeBalance
    df.at[0, "YearsAtCompany"] = YearsAtCompany
    df.at[0, "YearsInCurrentRole"] = YearsInCurrentRole
    df.at[0, "YearsSinceLastPromotion"] = YearsSinceLastPromotion
    df.at[0, "YearsWithCurrManager"] = YearsWithCurrManager
    
    # Predict the result
    result = Model.predict(df)[0]
    
    return result

def Main():
    st.title("Employee Turnover Prediction")
    
    Age = st.slider("Age", min_value=18, max_value=60, step=1, value=25)
    BusinessTravel = st.selectbox("Business Travel", ["Non-Travel", "Travel_Rarely", "Travel_Frequently"])
    DailyRate = st.slider("Daily Rate", min_value=102 , max_value=1499, step=10, value=200)
    Department = st.selectbox("Department", ['Sales','Research & Development', 'Human Resources'])
    DistanceFromHome = st.slider("Distance From Home", min_value=1, max_value=29, step=1, value=5)
    Education = st.selectbox("Education",  [1, 2, 3, 4,5])
    EducationField = st.selectbox("Education Field", ['Life Sciences', 'Other', 'Medical' ,'Marketing', 'Technical Degree' ,'Human Resources'])
    EnvironmentSatisfaction = st.selectbox("Environment Satisfaction", [1, 2, 3, 4])
    Gender = st.selectbox("Gender", ["Male", "Female"])
    HourlyRate = st.slider("Hourly Rate", min_value=30, max_value=100, step=1, value=30)
    JobInvolvement = st.selectbox("Job Involvement", [1, 2, 3, 4])
    JobLevel = st.selectbox("Job Level", [1, 2, 3, 4, 5])
    JobRole = st.selectbox("Job Role", ['Sales Executive' ,'Research Scientist', 'Laboratory Technician'
 ,'Manufacturing Director' ,'Healthcare Representative' ,'Manager',
 'Sales Representative' ,'Research Director', 'Human Resources'])
    JobSatisfaction = st.selectbox("Job Satisfaction", [1, 2, 3, 4])
    MaritalStatus = st.selectbox("Marital Status", ['Single', 'Married', 'Divorced'])
    MonthlyIncome = st.slider("Monthly Income", min_value=1009, max_value=19999, step=100, value=4000)
    MonthlyRate = st.slider("Monthly Rate", min_value=2094 , max_value=26999, step=100, value=2000)
    NumCompaniesWorked = st.slider("Number of Companies Worked", min_value=0, max_value=9, step=1, value=5)
    OverTime = st.selectbox("OverTime", ["No", "Yes"])
    PercentSalaryHike = st.slider("Percent Salary Hike", min_value=11, max_value=25, step=1, value=10)
    PerformanceRating = st.selectbox("Performance Rating", [ 3, 4])
    RelationshipSatisfaction = st.selectbox("Relationship Satisfaction", [1, 2, 3, 4])
    StockOptionLevel = st.selectbox("Stock Option Level", [0, 1, 2, 3])
    TotalWorkingYears = st.slider("Total Working Years", min_value=1, max_value=50, step=1, value=5)
    TrainingTimesLastYear = st.slider("Training Times Last Year", min_value=0, max_value=6, step=1, value=2)
    WorkLifeBalance = st.selectbox("Work Life Balance", [1, 2, 3, 4])
    YearsAtCompany = st.slider("Years at Company", min_value=0, max_value=40, step=1, value=5)
    YearsInCurrentRole = st.slider("Years in Current Role", min_value=0, max_value=18, step=1, value=2)
    YearsSinceLastPromotion = st.slider("Years Since Last Promotion", min_value=0, max_value=15, step=1, value=2)
    YearsWithCurrManager = st.slider("Years with Current Manager", min_value=0, max_value=17, step=1, value=3)
    
    if st.button("Predict"):
        result = prediction(Age, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, 
                            EducationField, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, 
                            JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, 
                            NumCompaniesWorked, OverTime, PercentSalaryHike, PerformanceRating, 
                            RelationshipSatisfaction, StockOptionLevel, TotalWorkingYears, 
                            TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, 
                            YearsSinceLastPromotion, YearsWithCurrManager)
        
        list_result = ["Rejected", "Accepted"]
        st.text(f"Your result is: {list_result[result]}")

Main()
# Out:
# 2024-12-21 18:40:14.211
# ...
#   command:
#
#     streamlit run C:\Users\Hossam\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# min ,max values for numerical columns
for col in Num_Columns:
    print(col,Num_Columns[col].min(),Num_Columns[col].max())
# Out:
# Age 18 60
# DailyRate 102 1499
# DistanceFromHome 1 29
# Education 1 5
# EnvironmentSatisfaction 1 4
# HourlyRate 30 100
# JobInvolvement 1 4
# JobLevel 1 5
# JobSatisfaction 1 4
# MonthlyIncome 1009 19999
# MonthlyRate 2094 26999
# NumCompaniesWorked 0 9
# PercentSalaryHike 11 25
# PerformanceRating 3 4
# RelationshipSatisfaction 1 4
# StockOptionLevel 0 3
# TotalWorkingYears 0 40
# TrainingTimesLastYear 0 6
# WorkLifeBalance 1 4
# YearsAtCompany 0 40
# YearsInCurrentRole 0 18
# YearsSinceLastPromotion 0 15
# YearsWithCurrManager 0 17

# %%
for col in Cat_Columns :
    print(f"{col}: {df[col].unique()}")
# Out:
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department: ['Sales' 'Research & Development' 'Human Resources']
# EducationField: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender: ['Female' 'Male']
# JobRole: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus: ['Single' 'Married' 'Divorced']
# OverTime: ['Yes' 'No']
